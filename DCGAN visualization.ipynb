# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/gdrive/My Drive/Kaggle'

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/Epsilon notebooks/My DCGAN
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Epsilon notebooks/My DCGAN

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/Epsilon notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Epsilon notebooks

# %%
mnist_predictor = load_model('CNN-MNIST.h5')

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import load_model
gen = load_model('mnist_generator.h5')

# %%
noise = tf.random.normal([10,100])
generated_image = gen.predict(noise)

n = len(generated_image)
plt.figure(figsize=(20, 4))
for i in range(n):

  ax = plt.subplot(2, n, i+1)
  plt.imshow(generated_image[i, :, :, 0], cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %%
noise = tf.random.normal([10,100])
generated_image = gen.predict(noise)

n = len(generated_image)
fig = plt.figure(figsize=(20, 4))
ax = []
for i in range(0, n):
  ax.append(fig.add_subplot(2, 5, i+1))
  ax[-1].set_title("This image is " + str(np.argmax(mnist_predictor.predict(generated_image[i].reshape(1,28,28,1)))))
  plt.imshow(generated_image[i, :, :, 0], cmap='gray')
  ax[-1].get_xaxis().set_visible(False)
  ax[-1].get_yaxis().set_visible(False)
